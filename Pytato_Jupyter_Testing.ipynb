# %%
import argparse
from Bio import SeqIO
from concurrent.futures import ThreadPoolExecutor
import csv
import os
import pandas as pd
from pathlib import Path
from pyteomics import parser,fasta,mass, mgf,auxiliary,mzml,pylab_aux
import re
import shutil
import subprocess

# %%
import matplotlib.pyplot as plt
import pylab
with mzml.PreIndexedMzML('tc_PlasmaEV_Benign_400to100_Rep2.mzML') as reader:
    i=next(reader)
    pylab.figure()
    pylab_aux.plot_spectrum(i)
    i=next(reader)
    pylab.figure()
    pylab_aux.plot_spectrum(i)
    i=next(reader)
    pylab.figure()
    pylab_aux.plot_spectrum(i)
