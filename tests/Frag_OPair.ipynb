# %%
import pandas as pd

# %%
df = pd.read_csv('Filter_Mods.txt', sep='\t')

# %%
df.columns
# Out:
# Index(['tc_2025June27_AscitesEV_Glycoproteomics_SAX_Full_Donor1 MaxLFQ Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Full_Donor2 MaxLFQ Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Full_Donor3 MaxLFQ Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Glyco_Donor1_20250627143138 MaxLFQ Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Glyco_Donor2_20250627154826 MaxLFQ Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Glyco_Donor3_20250627170517 MaxLFQ Intensity',
#        'tc_2025June30_AscitesEV_Glycoproteomics_SAX_Glyco_1ul_Donor1 MaxLFQ Intensity',
#        'tc_2025June30_AscitesEV_Glycoproteomics_SAX_Glyco_1ul_Donor2 MaxLFQ Intensity',
#        'tc_2025June30_AscitesEV_Glycoproteomics_SAX_Glyco_1ul_Donor3 MaxLFQ Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Full_Rep1 MaxLFQ Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Full_Rep2 MaxLFQ Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Full_Rep3 MaxLFQ Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Glyco_Rep1 MaxLFQ Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Glyco_Rep2 MaxLFQ Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Glyco_Rep3 MaxLFQ Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Full_Donor1 Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Full_Donor2 Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Full_Donor3 Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Glyco_Donor1_20250627143138 Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Glyco_Donor2_20250627154826 Intensity',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Glyco_Donor3_20250627170517 Intensity',
#        'tc_2025June30_AscitesEV_Glycoproteomics_SAX_Glyco_1ul_Donor1 Intensity',
#        'tc_2025June30_AscitesEV_Glycoproteomics_SAX_Glyco_1ul_Donor2 Intensity',
#        'tc_2025June30_AscitesEV_Glycoproteomics_SAX_Glyco_1ul_Donor3 Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Full_Rep1 Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Full_Rep2 Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Full_Rep3 Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Glyco_Rep1 Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Glyco_Rep2 Intensity',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Glyco_Rep3 Intensity',
#        'Assigned Modifications', 'Start', 'End', 'Charges', 'Peptide Length',
#        'Modified Sequence', 'Peptide Sequence', 'Gene', 'Protein',
#        'Protein ID', 'Prev AA', 'Next AA',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Full_Donor1 Localization',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Full_Donor2 Localization',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Full_Donor3 Localization',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Glyco_Donor1_20250627143138 Localization',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Glyco_Donor2_20250627154826 Localization',
#        'tc_2025June27_AscitesEV_Glycoproteomics_SAX_Glyco_Donor3_20250627170517 Localization',
#        'tc_2025June30_AscitesEV_Glycoproteomics_SAX_Glyco_1ul_Donor1 Localization',
#        'tc_2025June30_AscitesEV_Glycoproteomics_SAX_Glyco_1ul_Donor2 Localization',
#        'tc_2025June30_AscitesEV_Glycoproteomics_SAX_Glyco_1ul_Donor3 Localization',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Full_Rep1 Localization',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Full_Rep2 Localization',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Full_Rep3 Localization',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Glyco_Rep1 Localization',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Glyco_Rep2 Localization',
#        'tc_2025May08_AscitesEV_Glycoproteomics_SAX_Glyco_Rep3 Localization'],
#       dtype='object')

# %%
df.shape
# Out:
# (1229, 57)

# %%
import re
# Define the allowed modification masses
allowed_masses = {"42.0106", "15.9949", "57.0214"}

# Function to check for any unexpected modification
def has_unexpected_mod(mod_string):
    matches = re.findall(r'\(([^)]+)\)', mod_string)
    return any(m not in allowed_masses for m in matches)

# Filter the dataframe
df_filtered = df[df['Assigned Modifications'].apply(has_unexpected_mod)]

# Show result
df_filtered.shape
# Out:
# (921, 57)

# %% [markdown]
# # Rename columns to remove prefix up to and including "_Glycoproteomics_"

# %%
df_filtered.columns = df_filtered.columns.str.replace(r'.*_Glycoproteomics_', '', regex=True)

# %%
df_filtered.head(20)
df_filtered.to_excel('Filtered_Mods.xlsx')
